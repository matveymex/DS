# %%
import pandas 
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import NearestNeighbors
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import scale
from sklearn.datasets import load_boston
from sklearn.preprocessing import scale
from sklearn.neighbors import KNeighborsRegressor

# %%
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data', sep='\s+', error_bad_lines=False)

# %%
boston = load_boston()

# %%
boston.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
names = pd.read_excel('C:\\Users\\mmat9\\Downloads\\names_housing.xlsx', encoding="utf-8", error_bad_lines=False)

# %%
data.columns = names.name.tolist()

# %%
boston.data = scale(boston.data, axis=0, with_mean=True, with_std=True, copy=True)

# %%
p_values = np.linspace(1.0, 10.0, num=200)
kf = KFold(n_splits=5, random_state=42, shuffle=True)

# %%
cv_accuracy = [[p_i,cross_val_score(estimator=KNeighborsRegressor(n_neighbors=5, weights='distance', p=p_i, metric='minkowski'), X=boston.data, y=boston.target, cv=kf).mean()] for p_i in p_values]

# %%
m=0
cv_accuracy_max =[]
[cv_accuracy_max == cv_accuracy[i] for i in range(len(cv_accuracy)) 
 if cv_accuracy[i][1]>cv_accuracy_max[1][1]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-114-05442002eb91> in <module>
#       1 m=0
#       2 cv_accuracy_max =[]
# ----> 3 [cv_accuracy_max == cv_accuracy[i] for i in range(len(cv_accuracy))
#       4  if cv_accuracy[i][1]>cv_accuracy_max[1][1]]
#
# <ipython-input-114-05442002eb91> in <listcomp>(.0)
#       2 cv_accuracy_max =[]
#       3 [cv_accuracy_max == cv_accuracy[i] for i in range(len(cv_accuracy))
# ----> 4  if cv_accuracy[i][1]>cv_accuracy_max[1][1]]
#
# IndexError: list index out of range

# %%
i, item = max(enumerate(cv_accuracy), key=lambda pair: (pair[0], pair[1]))

# %%
cv_accuracy[m][1]
# Out:
# 0.8013825191275472

# %% [markdown]
# # len(cv_accuracy)

# %%
cv_accuracy
# Out:
# [[1.0, 0.8013825191275472],
#  [1.0452261306532664, 0.7964902267716104],
#  [1.0904522613065326, 0.7970351994890925],
#  [1.135678391959799, 0.7960441449462369],
#  [1.1809045226130652, 0.7958525038656383],
#  [1.2261306532663316, 0.7952144445064107],
#  [1.271356783919598, 0.7937827040268853],
#  [1.3165829145728645, 0.7916284113617571],
#  [1.3618090452261307, 0.7910927683768262],
#  [1.4070351758793969, 0.7883630514366112],
#  [1.4522613065326633, 0.7882140547442946],
#  [1.4974874371859297, 0.7899912579171211],
#  [1.542713567839196, 0.7892834133384248],
#  [1.5879396984924623, 0.7935965767193268],
#  [1.6331658291457287, 0.7917882508886473],
#  [1.678391959798995, 0.7913626401674062],
#  [1.7236180904522613, 0.7897891368108612],
#  [1.7688442211055277, 0.7896838574198888],
#  [1.814070351758794, 0.7894985303610784],
#  [1.8592964824120604, 0.788386699049035],
#  [1.9045226130653266, 0.7873190205017475],
#  [1.949748743718593, 0.7879022722953434],
# ...

# %%
i
# Out:
# 199

# %%
i, item = max((i,v) for i,v in enumerate(cv_accuracy))
